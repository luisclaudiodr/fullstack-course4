# %% [markdown]
# <a href="https://colab.research.google.com/github/luisclaudiodr/fullstack-course4/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Inicial Colab**

# %%
print("teste")
# Out:
# teste

# %% [markdown]
# ### **1. Exemplo grafico**

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
